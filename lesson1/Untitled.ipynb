# %%
pip install numpy
# Out:
# ...
#
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ------------------------- ------------ 41.0/61.0 kB 653.6 kB/s eta 0:00:01
#      -------------------------------------- 61.0/61.0 kB 806.3 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.8 MB 1.3 MB/s eta 0:00:13
#    ---------------------------------------- 0.1/15.8 MB 871.5 kB/s eta 0:00:19
#    ---------------------------------------- 0.2/15.8 MB 1.3 MB/s eta 0:00:12
#     --------------------------------------- 0.4/15.8 MB 2.0 MB/s eta 0:00:08
#    - -------------------------------------- 0.6/15.8 MB 2.8 MB/s eta 0:00:06
#    -- ------------------------------------- 0.8/15.8 MB 3.0 MB/s eta 0:00:05
#    -- ------------------------------------- 0.9/15.8 MB 2.8 MB/s eta 0:00:06
#    -- ------------------------------------- 1.1/15.8 MB 3.2 MB/s eta 0:00:05
# ...

# %%
import numpy as np

# %%
random_int_array = np.random.randint(1,50, size=(5,2))

# %%
random_int_array.size
# Out:
# 10

# %%
random_int_array.shape
# Out:
# (5, 2)

# %%
random_int_array.type
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 random_int_array.type
#
# AttributeError: 'numpy.ndarray' object has no attribute 'type'

# %%
random_int_array.dtype
# Out:
# dtype('int32')

# %%
random_int_array = np.random.randint(10,100, size=(2,5))

# %%
random_int_array.shape
# Out:
# (2, 5)

# %%
random_int_array.ndim
# Out:
# 2

# %%
random_int_array = np.random.randint(1,50, size=(5,2))

# %%
np.mean(random_int_array)
# Out:
# 23.8

# %%
random_int_array1 = np.random.randint(1,50, size=(1,2))
random_int_array2 = np.random.randint(1,50, size=(1,2))

# %%
arr12=random_int_array1+random_int_array2

# %%
np.mean(arr12)
# Out:
# 78.0

# %%
random_int_array2 = np.random.randint(1,100, size=(2,10))

# %%
random_int_array2 = np.random.randint(1,100, size=(2,10))
random_int_array2=arr1[arr1>50]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 random_int_array2 = np.random.randint(1,100, size=(2,10))
# ----> 2 random_int_array2=arr1[arr1>50]
#
# NameError: name 'arr1' is not defined

# %%
random_int_array2 = np.random.randint(1,100, size=(2,10))
random_int_array1=random_int_array2[random_int_array2>50]

# %%
random_int_array2 = np.random.randint(1,100, size=(10))

# %%
np.shuffle(random_int_array2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 np.shuffle(random_int_array2)
#
# File C:\Python310\lib\site-packages\numpy\__init__.py:347, in __getattr__(attr)
#     344     "Removed in NumPy 1.25.0"
#     345     raise RuntimeError("Tester was removed in NumPy 1.25.")
# --> 347 raise AttributeError("module {!r} has no attribute "
#     348                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'shuffle'

# %%
np.random.shuffle(random_int_array2)
