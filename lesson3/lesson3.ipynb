# %%
pip install pandas
# Out:
# ...
#
# ...
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
data = {'שם': ['אליז', 'בת שבע', 'גליה'],
        'כיתה': ["ג", 'ב',"א"],
        'ממוצע ציונים': [100, 85, 98]}

# %%
sample = pd.DataFrame(data)
sample
# Out:
#        שם כיתה  ממוצע ציונים
# 0    אליז    ג           100
# 1  בת שבע    ב            85
# 2    גליה    א            98

# %%
sample["C"] = [10, 20, 30]
sample
# Out:
#        שם כיתה  ממוצע ציונים   C
# 0    אליז    ג           100  10
# 1  בת שבע    ב            85  20
# 2    גליה    א            98  30

# %%
new_row = {'name': 'John', 'age': 35, 'city': 'New York'}
sample.loc[len(sample)] = new_row

# %%
df = pd.read_csv("Z:\mora\פייתון מתקדם\שיעור 5\cities.csv")
df
# Out:
#      LatD   "LatM"  LatS    NS  LonD   LonM""   "LonS"    EW  \
# 0      41        5    59   "N"    80       39        0   "W"
# 1      42       52    48   "N"    97       23       23   "W"
# 2      46       35    59   "N"   120       30       36   "W"
# 3      42       16    12   "N"    71       48        0   "W"
# 4      43       37    48   "N"    89       46       11   "W"
# ..    ...      ...   ...   ...   ...      ...      ...   ...
# 123    39       31    12   "N"   119       48       35   "W"
# 124    50       25    11   "N"   104       39        0   "W"
# 125    40       10    48   "N"   122       14       23   "W"
# 126    40       19    48   "N"    75       55       48   "W"
# 127    41        9    35   "N"    81       14       23   "W"
#
#                    City  State
# 0          "Youngstown"     OH
# 1             "Yankton"     SD
# 2              "Yakima"     WA
# 3           "Worcester"     MA
# 4     "Wisconsin Dells"     WI
# ..                  ...    ...
# ...

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.LatD = df.LatD.fillna("no model selected")

# %%
df.drop_duplicates()
# Out:
#      LatD   "LatM"  LatS    NS  LonD   LonM""   "LonS"  "EW"  \
# 0      41        5    59   "N"    80       39        0   "W"
# 1      42       52    48   "N"    97       23       23   "W"
# 2      46       35    59   "N"   120       30       36   "W"
# 3      42       16    12   "N"    71       48        0   "W"
# 4      43       37    48   "N"    89       46       11   "W"
# ..    ...      ...   ...   ...   ...      ...      ...   ...
# 123    39       31    12   "N"   119       48       35   "W"
# 124    50       25    11   "N"   104       39        0   "W"
# 125    40       10    48   "N"   122       14       23   "W"
# 126    40       19    48   "N"    75       55       48   "W"
# 127    41        9    35   "N"    81       14       23   "W"
#
#                  City""  State
# 0          "Youngstown"     OH
# 1             "Yankton"     SD
# 2              "Yakima"     WA
# 3           "Worcester"     MA
# 4     "Wisconsin Dells"     WI
# ..                  ...    ...
# ...

# %%
df["LonD"].mean()
# Out:
# 93.25

# %%
min = df["LonD"].min()
min
# Out:
# 71

# %%
df['chevi']=df['LonD']/df['LatS']
df
# Out:
#      LatD   "LatM"  LatS    NS  LonD   LonM""   "LonS"    EW  \
# 0      41        5    59   "N"    80       39        0   "W"
# 1      42       52    48   "N"    97       23       23   "W"
# 2      46       35    59   "N"   120       30       36   "W"
# 3      42       16    12   "N"    71       48        0   "W"
# 4      43       37    48   "N"    89       46       11   "W"
# ..    ...      ...   ...   ...   ...      ...      ...   ...
# 123    39       31    12   "N"   119       48       35   "W"
# 124    50       25    11   "N"   104       39        0   "W"
# 125    40       10    48   "N"   122       14       23   "W"
# 126    40       19    48   "N"    75       55       48   "W"
# 127    41        9    35   "N"    81       14       23   "W"
#
#                    City  State     chevi
# 0          "Youngstown"     OH  1.355932
# 1             "Yankton"     SD  2.020833
# 2              "Yakima"     WA  2.033898
# 3           "Worcester"     MA  5.916667
# ...

# %%
df[df.LatD==41].sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 df[df.LatD==41].sort_values(ascending=False)
#
# TypeError: DataFrame.sort_values() missing 1 required positional argument: 'by'
